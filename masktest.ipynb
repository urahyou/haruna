# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np

# %%
img1 = mpimg.imread('shell/surface0000.pna') # 读取和代码处于同一目录下的 lena.png

#结果展示
plt.subplot(121)
#imshow()对图像进行处理，画出图像，show()进行图像显示
plt.imshow(img1)


# #设置子图默认的间距
plt.tight_layout()
#显示图像
plt.show()

# %%
plt.imshow(img1[:,:,1])

# %%
img2 = mpimg.imread('shell/mymask.png')

# %%
img2.shape
# Out:
# (344, 300)

# %%
img2[img2<1]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
img1.shape
# Out:
# (344, 300, 4)

# %%
plt.imshow(img2)

# %%
img1 = 1-img1[:,:,0]

# %%
img2.shape
# Out:
# (344, 300)

# %%
img3 = mpimg.imread('./shell/surface0001.png')

# %%
plt.imshow((img3[:,:,0]>0).astype('int'))

# %%
(img3[:,:,0]>0).astype('int')
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
mpimg.imsave('mask001.png',(1-(img3[:,:,0]>0).astype('int')))

# %%
from glob import glob

# %%
files = ('shell/surface/surface*png')

# %%
for file in files:
    img = mpimg.imread(file)
